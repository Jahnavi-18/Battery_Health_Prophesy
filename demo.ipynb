# %%
import matplotlib.pyplot as plt
from scipy.io import loadmat

# Load the .mat file
mat_data = loadmat("B0005.mat")

# Extract the variable 'a' from the loaded data
data = mat_data['B0005'][0][0][0][0]
a = data[-1][-1][-1][-1]

# Create the line plot
plt.plot(a)

# Add labels and title if needed
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot of Variable "a"')

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\Urop\demo.ipynb Cell 1 line 1
#       <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> a = data[-1][-1][-1][-1]
#      <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a> # Create the line plot
# ---> <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a> plt.plot(a)
#      <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W0sZmlsZQ%3D%3D?line=13'>14</a> # Add labels and title if needed
#      <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W0sZmlsZQ%3D%3D?line=14'>15</a> plt.xlabel('X-axis')
#
# File c:\Users\MARUTHI\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
# ...

# %%
import matplotlib.pyplot as plt
from scipy.io import loadmat
import numpy as np

# Load the .mat file
mat_data = loadmat("B0005.mat")

# Extract the structured array
data = mat_data['B0005'][0][0][0][0]

# List the available field names
field_names = data.dtype.names
print("Available field names:", field_names)

# Select and extract the field you want to plot (e.g., 'Voltage_measured')
selected_field = 'discharge'
y_values = data[selected_field][0]

# Create the line plot
plt.plot(y_values)

# Add labels and title if needed
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title(f'Line Plot of {selected_field}')

# Display the plot
plt.show()
# Out:
# Available field names: ('type', 'ambient_temperature', 'time', 'data')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\Urop\demo.ipynb Cell 2 line 1
#      <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W3sZmlsZQ%3D%3D?line=14'>15</a> # Select and extract the field you want to plot (e.g., 'Voltage_measured')
#      <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W3sZmlsZQ%3D%3D?line=15'>16</a> selected_field = 'discharge'
# ---> <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W3sZmlsZQ%3D%3D?line=16'>17</a> y_values = data[selected_field][0]
#      <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W3sZmlsZQ%3D%3D?line=18'>19</a> # Create the line plot
#      <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W3sZmlsZQ%3D%3D?line=19'>20</a> plt.plot(y_values)
#
# ValueError: no field of name discharge

# %%
pip install ipykernel
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from scipy.io import loadmat

# Load the .mat file
mat_data = loadmat("B0005.mat")

# Extract the variable containing the discharge data (you might need to adjust this part based on your data structure)
discharge_data = mat_data['Capacity']

# Create a line plot of the discharge data
plt.plot(discharge_data)

# Add labels and title if needed
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Discharge Data')

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# e:\Urop\demo.ipynb Cell 4 line 8
#       <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> mat_data = loadmat("B0005.mat")
#       <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> # Extract the variable containing the discharge data (you might need to adjust this part based on your data structure)
# ----> <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> discharge_data = mat_data['Capacity']
#      <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a> # Create a line plot of the discharge data
#      <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a> plt.plot(discharge_data)
#
# KeyError: 'Capacity'

# %%
import matplotlib.pyplot as plt
from scipy.io import loadmat

# Load the .mat file
mat_data = loadmat("B0005.mat")

# Extract the main data array
data = mat_data['B0005']

# Iterate through rows and select the one(s) with 'discharge'
for row in data[0][0][0][0]:
    if row[0] == 'discharge':
        discharge_data = row[-1][-1][-1][-1]

# Create a line plot of the discharge data
plt.plot(discharge_data)

# Add labels and title if needed
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Discharge Data')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy.io import loadmat

# Load the .mat file
mat_data = loadmat("B0005.mat")

# Extract the main data array
data = mat_data['B0005']

# Initialize a list to store the discharge data
discharge_data = []

# Iterate through rows and select the one(s) with 'discharge'
for row in data[0][0][0][0]:
    if row[0][0] == 'discharge':
        discharge_data.extend(row[-1][0])

# Create a line plot of the discharge data
plt.plot(discharge_data)

# Add labels and title if needed
plt.xlabel('Time')
plt.ylabel('Discharge Value')
plt.title('Discharge Data')

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\Urop\demo.ipynb Cell 6 line 1
#      <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W5sZmlsZQ%3D%3D?line=15'>16</a>         discharge_data.extend(row[-1][0])
#      <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W5sZmlsZQ%3D%3D?line=17'>18</a> # Create a line plot of the discharge data
# ---> <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W5sZmlsZQ%3D%3D?line=18'>19</a> plt.plot(discharge_data)
#      <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W5sZmlsZQ%3D%3D?line=20'>21</a> # Add labels and title if needed
#      <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#W5sZmlsZQ%3D%3D?line=21'>22</a> plt.xlabel('Time')
#
# File c:\Users\MARUTHI\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt
from scipy.io import loadmat

# Load the .mat file
mat_data = loadmat("B0005.mat")

# Extract the main data array
data = mat_data['B0005'][0][0][0][0]

# Find the index of the field containing 'discharge' (e.g., 'Capacity')
field_names = [field[0] for field in data]
discharge_index = field_names.index('Capacity')

# Extract the discharge data from the identified field
discharge_data = data[discharge_index][-1][0]

# Create a line plot of the discharge data
plt.plot(discharge_data)

# Add labels and title if needed
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Discharge Data')

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\Urop\demo.ipynb Cell 8 line 1
#      <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a> # Find the index of the field containing 'discharge' (e.g., 'Capacity')
#      <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#X10sZmlsZQ%3D%3D?line=10'>11</a> field_names = [field[0] for field in data]
# ---> <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a> discharge_index = field_names.index('Capacity')
#      <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#X10sZmlsZQ%3D%3D?line=13'>14</a> # Extract the discharge data from the identified field
[[1.32387242]]
[[1.36012168]]
[[1.33953069]]
[[1.32902866]]
[[1.32367413]]
[[1.3186339]]
[[1.31347513]]
[[1.31320206]]
[[1.30779599]]
[[1.30303292]]
[[1.30335736]]
[[1.30341004]]
[[1.29788708]]
[[1.29807351]]
[[1.29346361]]
[[1.28800339]]
[[1.28745252]]
[[1.30901536]]
[[1.32507933]]
]

# Extract the x values (assuming it's just a sequence of numbers)
x_values = list(range(1, len(discharge_data) + 1))

# Create a line plot
plt.plot(x_values, discharge_data)

# Add labels and title
plt.xlabel('Data Point Index')
plt.ylabel('Discharge Value')
plt.title('Discharge Data Line Plot')

# Show the plot
plt.show()
# Out:
# <>:5: SyntaxWarning: list indices must be integers or slices, not list; perhaps you missed a comma?
# <>:5: SyntaxWarning: list indices must be integers or slices, not list; perhaps you missed a comma?
# C:\Users\MARUTHI\AppData\Local\Temp\ipykernel_12204\3844487409.py:5: SyntaxWarning: list indices must be integers or slices, not list; perhaps you missed a comma?
#   [[1.85648742]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\Urop\demo.ipynb Cell 9 line 5
#       <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> # The data you provided
#       <a href='vscode-notebook-cell:/e%3A/Urop/demo.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> discharge_data = [
# ...

# %%
import numpy as num
data = [
    [1.85648742], [1.84632725], [1.83534919], [1.83526253], [1.83464551], [1.83566166], [1.83514614], [1.82575679],
    [1.82477385], [1.82461327], [1.82461955], [1.81420194], [1.81375216], [1.81344049], [1.802598], [1.8021069],
    [1.8025795], [1.80306831], [1.80277762], [1.84702599], [1.84741731], [1.83617742], [1.82578075], [1.82511364],
    [1.8255815], [1.81403113], [1.81476919], [1.81396939], [1.80276567], [1.80407704], [1.85180255], [1.83070385],
    [1.81990411], [1.80930796], [1.8046099], [1.79937707], [1.78844323], [1.78292305], [1.77303372], [1.77303776],
    [1.76787211], [1.76231507], [1.76761729], [1.76266836], [1.75173049], [1.7418496], [1.73609135], [1.79362401],
    [1.78318902], [1.76736421], [1.75701779], [1.74687062], [1.74171725], [1.73642251], [1.72632172], [1.71580654],
    [1.71053335], [1.7060145], [1.70031103], [1.69457986], [1.68490291], [1.67447416], [1.67456925], [1.66371638],
    [1.65901387], [1.65385406], [1.64265378], [1.63785784], [1.63273504], [1.62775289], [1.62212549], [1.61132566],
    [1.60656314], [1.60151422], [1.59036923], [1.585789], [1.58494307], [1.59552639], [1.57473017], [1.564902],
    [1.55976595], [1.55948157], [1.55468935], [1.54887411], [1.5382366], [1.52791426], [1.52852526], [1.52264733],
    [1.51748599], [1.6058189], [1.56384914], [1.54809152], [1.53237556], [1.52695283], [1.5169573], [1.5118976],
    [1.5065639], [1.50154535], [1.49084441], [1.48586838], [1.48041368], [1.47520959], [1.4859036], [1.49609183],
    [1.48080059], [1.46975433], [1.45390123], [1.45414621], [1.45502375], [1.44904216], [1.43867094], [1.43344543],
    [1.43339589], [1.42806487], [1.42292032], [1.41742903], [1.41240923], [1.41257879], [1.40759837], [1.43339205],
    [1.43825502], [1.41735472], [1.40698166], [1.40120378], [1.39670082], [1.39128479], [1.38622877], [1.38043668],
    [1.37523642], [1.3705128], [1.37050856], [1.36473551], [1.37539202], [1.38611152], [1.36985], [1.36478279],
    [1.35432205], [1.3546417], [1.35470392], [1.349315], [1.34418919], [1.33899138], [1.33891452], [1.33400668], [1.32864443], [1.3231709], [1.31816916], [1.31846644], [1.31829304], [1.32387242],
    [1.36012168], [1.33953069], [1.32902866], [1.32367413], [1.3186339], [1.31347513], [1.31320206], [1.30779599], [1.30303292],
    [1.30335736], [1.30341004], [1.29788708], [1.29807351], [1.29346361], [1.28800339], [1.28745252], [1.30901536], [1.32507933]
]

# Convert to a NumPy array
data_array = np.array(data)

# Print the array
print(data_array)
# Out:
# [[1.85648742]
#  [1.84632725]
#  [1.83534919]
#  [1.83526253]
#  [1.83464551]
#  [1.83566166]
#  [1.83514614]
#  [1.82575679]
#  [1.82477385]
#  [1.82461327]
#  [1.82461955]
#  [1.81420194]
#  [1.81375216]
#  [1.81344049]
#  [1.802598  ]
#  [1.8021069 ]
#  [1.8025795 ]
#  [1.80306831]
#  [1.80277762]
#  [1.84702599]
#  [1.84741731]
#  [1.83617742]
#  [1.82578075]
#  [1.82511364]
#  [1.8255815 ]
#  [1.81403113]
#  [1.81476919]
#  [1.81396939]
#  [1.80276567]
#  [1.80407704]
#  [1.85180255]
#  [1.83070385]
#  [1.81990411]
#  [1.80930796]
#  [1.8046099 ]
#  [1.79937707]
#  [1.78844323]
#  [1.78292305]
#  [1.77303372]
#  [1.77303776]
#  [1.76787211]
#  [1.76231507]
#  [1.76761729]
#  [1.76266836]
#  [1.75173049]
#  [1.7418496 ]
#  [1.73609135]
#  [1.79362401]
#  [1.78318902]
#  [1.76736421]
#  [1.75701779]
#  [1.74687062]
#  [1.74171725]
#  [1.73642251]
#  [1.72632172]
#  [1.71580654]
#  [1.71053335]
#  [1.7060145 ]
#  [1.70031103]
#  [1.69457986]
#  [1.68490291]
#  [1.67447416]
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(data)
plt.show()

# %%
from scipy.io import loadmat
import pandas as pd
import matplotlib.pyplot as plt
mat_data = loadmat("B0005.mat")
data = mat_data['B0005']

capacity = []

for row in data[0][0][0][0]:
    if row[0] == ['discharge']:
        capacity.append(row[-1][-1][-1][-1][0][0])
        
print(capacity)
# Out:
# [1.8564874208181574, 1.846327249719927, 1.8353491942234077, 1.8352625275821128, 1.8346455082120419, 1.8356616600675495, 1.8351461429226603, 1.8257567905665537, 1.8247738529891333, 1.824613268496936, 1.8246195526864504, 1.8142019357673917, 1.8137521577549054, 1.8134404914735822, 1.8025980036306504, 1.80210690024615, 1.802579500826209, 1.8030683142834096, 1.8027776247196041, 1.8470259949329193, 1.847417311283644, 1.8361774213478947, 1.8257807475776242, 1.8251136435078368, 1.8255815042203762, 1.8140311275083907, 1.8147691941158939, 1.813969388710352, 1.802765665167823, 1.804077040117352, 1.8518025516704486, 1.8307038456739428, 1.8199041089501267, 1.8093079637028517, 1.80460990458052, 1.7993770651972192, 1.7884432335370462, 1.7829230484252723, 1.7730337158018288, 1.773037755078937, 1.7678721106662054, 1.7623150704093087, 1.7676172924938447, 1.762668359743147, 1.7517304870664143, 1.7418496047960008, 1.7360913511847138, 1.7936240148573608, 1.7831890223273275, 1.7673642076278957, 1.75701778
# ...

# %%
plt.plot(capacity)
plt.show()
